# %%
#Logistic Regression Analysis
#Step:1 Import required libraries
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# %%
#Step:2 Generate the dataset for Logistic Regression
# Making our own dataset here!
x, y = make_classification(n_samples=90, n_features=1, n_classes=2, n_clusters_per_class=1, flip_y=0.03, n_informative=1, n_redundant=0, n_repeated=0)

# %%
#PLotting
plt.scatter(x,y,c=y,cmap='rainbow')
plt.title('Scatter plot of Logistic Regression')
plt.grid(True)
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30,random_state=0)

# %%
mod = LogisticRegression()
mod.fit(x_train,y_train)
y_pred = mod.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        16
#            1       0.92      1.00      0.96        11
#
#     accuracy                           0.96        27
#    macro avg       0.96      0.97      0.96        27
# weighted avg       0.97      0.96      0.96        27

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[12,  2],
#        [ 0, 13]], dtype=int64)
